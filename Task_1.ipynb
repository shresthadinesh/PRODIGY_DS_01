# %% [markdown]
# # Task 1

# %% [markdown]
# #### Create a bar chart or histogram to visualize the distribution of a categorical or continuous variable, such as the distribution of ages or genders in a population.

# %% [markdown]
# ### About The Dataset

# %% [markdown]
# #### We have taken a World Population Dataset consisting records of population from the year 2001 to 2022.

# %%
# Importing the necessary library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read the dataset
df = pd.read_csv("Population.csv")

# %%
df.head()
# Out:
#          Series Name  Series Code    Country Name Country Code        2022  \
# 0  Population, total  SP.POP.TOTL     Afghanistan          AFG  41128771.0
# 1  Population, total  SP.POP.TOTL         Albania          ALB   2775634.0
# 2  Population, total  SP.POP.TOTL         Algeria          DZA  44903225.0
# 3  Population, total  SP.POP.TOTL  American Samoa          ASM     44273.0
# 4  Population, total  SP.POP.TOTL         Andorra          AND     79824.0
#
#          2021        2020        2019        2018        2017  ...  \
# 0  40099462.0  38972230.0  37769499.0  36686784.0  35643418.0  ...
# 1   2811666.0   2837849.0   2854191.0   2866376.0   2873457.0  ...
# 2  44177969.0  43451666.0  42705368.0  41927007.0  41136546.0  ...
# 3     45035.0     46189.0     47321.0     48424.0     49463.0  ...
# 4     79034.0     77700.0     76343.0     75013.0     73837.0  ...
#
#          2010        2009        2008        2007        2006        2005  \
# ...

# %%
df.tail()
# Out:
#                                    Series Name        Series Code  \
# 1080  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1081  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1082  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1083  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1084  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
#
#                Country Name Country Code       2022       2021       2020  \
# 1080  Virgin Islands (U.S.)          VIR  46.613382  46.764444  46.914637
# 1081     West Bank and Gaza          PSE  49.893678  49.877839  49.858957
# 1082            Yemen, Rep.          YEM  50.519031  50.538516  50.554317
# 1083                 Zambia          ZMB  49.344602  49.344951  49.338301
# 1084               Zimbabwe          ZWE  47.214139  47.167153  47.130679
#
#            2019       2018       2017  ...       2010       2009       2008  \
# ...

# %%
df.shape
# Out:
# (1085, 26)

# %%
df.columns
# Out:
# Index(['Series Name', 'Series Code', 'Country Name', 'Country Code', '2022',
#        '2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013',
#        '2012', '2011', '2010', '2009', '2008', '2007', '2006', '2005', '2004',
#        '2003', '2002', '2001'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1085 entries, 0 to 1084
# Data columns (total 26 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Series Name   1085 non-null   object
#  1   Series Code   1085 non-null   object
#  2   Country Name  1085 non-null   object
#  3   Country Code  1085 non-null   object
#  4   2022          1085 non-null   float64
#  5   2021          1085 non-null   float64
#  6   2020          1085 non-null   float64
#  7   2019          1085 non-null   float64
#  8   2018          1085 non-null   float64
#  9   2017          1085 non-null   float64
#  10  2016          1085 non-null   float64
#  11  2015          1085 non-null   float64
#  12  2014          1085 non-null   float64
#  13  2013          1085 non-null   float64
#  14  2012          1085 non-null   float64
#  15  2011          1085 non-null   float64
#  16  2010          1085 non-null   float64
# ...

# %%
df.describe()
# Out:
#                2022          2021          2020          2019          2018  \
# count  1.085000e+03  1.085000e+03  1.085000e+03  1.085000e+03  1.085000e+03
# mean   1.461378e+07  1.449711e+07  1.437307e+07  1.422876e+07  1.407966e+07
# std    7.832944e+07  7.801505e+07  7.763257e+07  7.712985e+07  7.657562e+07
# min    2.749000e+01  2.732503e+01  2.735104e+01  2.676295e+01  2.573928e+01
# 25%    5.034029e+01  5.035172e+01  5.034171e+01  5.033040e+01  5.033917e+01
# 50%    1.465500e+05  1.463660e+05  1.461650e+05  1.459570e+05  1.457520e+05
# 75%    5.903468e+06  5.856733e+06  5.831404e+06  5.814422e+06  5.774185e+06
# max    1.417173e+09  1.412360e+09  1.411100e+09  1.407745e+09  1.402760e+09
#
#                2017          2016          2015          2014          2013  \
# count  1.085000e+03  1.085000e+03  1.085000e+03  1.085000e+03  1.085000e+03
# mean   1.392568e+07  1.376711e+07  1.360705e+07  1.344625e+07  1.328368e+07
# ...

# %% [markdown]
# ## Checking for duplicate values

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1080    False
# 1081    False
# 1082    False
# 1083    False
# 1084    False
# Length: 1085, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
## there is no duplicate rowsin datadet

# %% [markdown]
# ## Checking missing values

# %%
df.isnull()
# Out:
#       Series Name  Series Code  Country Name  Country Code   2022   2021  \
# 0           False        False         False         False  False  False
# 1           False        False         False         False  False  False
# 2           False        False         False         False  False  False
# 3           False        False         False         False  False  False
# 4           False        False         False         False  False  False
# ...           ...          ...           ...           ...    ...    ...
# 1080        False        False         False         False  False  False
# 1081        False        False         False         False  False  False
# 1082        False        False         False         False  False  False
# 1083        False        False         False         False  False  False
# 1084        False        False         False         False  False  False
#
#        2020   2019   2018   2017  ...   2010   2009   2008   2007   2006  \
# ...

# %%
df.isnull().sum()
# Out:
# Series Name     0
# Series Code     0
# Country Name    0
# Country Code    0
# 2022            0
# 2021            0
# 2020            0
# 2019            0
# 2018            0
# 2017            0
# 2016            0
# 2015            0
# 2014            0
# 2013            0
# 2012            0
# 2011            0
# 2010            0
# 2009            0
# 2008            0
# 2007            0
# 2006            0
# 2005            0
# 2004            0
# 2003            0
# 2002            0
# 2001            0
# dtype: int64

# %%
## there is no missing values in dataset

# %% [markdown]
# ## Checking unique values for columns

# %%
df.nunique()
# Out:
# Series Name        5
# Series Code        5
# Country Name     217
# Country Code     217
# 2022            1085
# 2021            1085
# 2020            1085
# 2019            1085
# 2018            1085
# 2017            1085
# 2016            1085
# 2015            1085
# 2014            1085
# 2013            1085
# 2012            1084
# 2011            1085
# 2010            1084
# 2009            1085
# 2008            1085
# 2007            1085
# 2006            1085
# 2005            1085
# 2004            1085
# 2003            1085
# 2002            1085
# 2001            1085
# dtype: int64

# %%
df['Country Code']
# Out:
# 0       AFG
# 1       ALB
# 2       DZA
# 3       ASM
# 4       AND
#        ...
# 1080    VIR
# 1081    PSE
# 1082    YEM
# 1083    ZMB
# 1084    ZWE
# Name: Country Code, Length: 1085, dtype: object

# %%
df['Country Code'].unique()
# Out:
# array(['AFG', 'ALB', 'DZA', 'ASM', 'AND', 'AGO', 'ATG', 'ARG', 'ARM',
#        'ABW', 'AUS', 'AUT', 'AZE', 'BHS', 'BHR', 'BGD', 'BRB', 'BLR',
#        'BEL', 'BLZ', 'BEN', 'BMU', 'BTN', 'BOL', 'BIH', 'BWA', 'BRA',
#        'VGB', 'BRN', 'BGR', 'BFA', 'BDI', 'CPV', 'KHM', 'CMR', 'CAN',
#        'CYM', 'CAF', 'TCD', 'CHI', 'CHL', 'CHN', 'COL', 'COM', 'COD',
#        'COG', 'CRI', 'CIV', 'HRV', 'CUB', 'CUW', 'CYP', 'CZE', 'DNK',
#        'DJI', 'DMA', 'DOM', 'ECU', 'EGY', 'SLV', 'GNQ', 'ERI', 'EST',
#        'SWZ', 'ETH', 'FRO', 'FJI', 'FIN', 'FRA', 'PYF', 'GAB', 'GMB',
#        'GEO', 'DEU', 'GHA', 'GIB', 'GRC', 'GRL', 'GRD', 'GUM', 'GTM',
#        'GIN', 'GNB', 'GUY', 'HTI', 'HND', 'HKG', 'HUN', 'ISL', 'IND',
#        'IDN', 'IRN', 'IRQ', 'IRL', 'IMN', 'ISR', 'ITA', 'JAM', 'JPN',
#        'JOR', 'KAZ', 'KEN', 'KIR', 'PRK', 'KOR', 'XKX', 'KWT', 'KGZ',
#        'LAO', 'LVA', 'LBN', 'LSO', 'LBR', 'LBY', 'LIE', 'LTU', 'LUX',
# ...

# %%
print("The total number of unique country code : ", df['Country Code'].nunique())
# Out:
# The total number of unique country code :  217

# %%
df['Series Name'].unique()
# Out:
# array(['Population, total', 'Population, female', 'Population, male',
#        'Population, female (% of total population)',
#        'Population, male (% of total population)'], dtype=object)

# %%
df['Series Code'].unique()
# Out:
# array(['SP.POP.TOTL', 'SP.POP.TOTL.FE.IN', 'SP.POP.TOTL.MA.IN',
#        'SP.POP.TOTL.FE.ZS', 'SP.POP.TOTL.MA.ZS'], dtype=object)

# %% [markdown]
# ## Dropping unnecessary columns

# %%
df.drop(['Series Name','Country Code'], axis = 1, inplace = True)
# .drop() is used to remove the rows and columns
# ['Series Name', 'Country Code']	List of column names to be dropped.
# axis=1	Specifies that we are dropping columns (not rows).
# inplace=True	Modifies the DataFrame directly without returning a new one.

# %%
df.columns
# Out:
# Index(['Series Code', 'Country Name', '2022', '2021', '2020', '2019', '2018',
#        '2017', '2016', '2015', '2014', '2013', '2012', '2011', '2010', '2009',
#        '2008', '2007', '2006', '2005', '2004', '2003', '2002', '2001'],
#       dtype='object')

# %% [markdown]
# ## Extracting the Top 15 Countries by Population (2022)

# %%
df.head()
# Out:
#    Series Code    Country Name        2022        2021        2020  \
# 0  SP.POP.TOTL     Afghanistan  41128771.0  40099462.0  38972230.0
# 1  SP.POP.TOTL         Albania   2775634.0   2811666.0   2837849.0
# 2  SP.POP.TOTL         Algeria  44903225.0  44177969.0  43451666.0
# 3  SP.POP.TOTL  American Samoa     44273.0     45035.0     46189.0
# 4  SP.POP.TOTL         Andorra     79824.0     79034.0     77700.0
#
#          2019        2018        2017        2016        2015  ...  \
# 0  37769499.0  36686784.0  35643418.0  34636207.0  33753499.0  ...
# 1   2854191.0   2866376.0   2873457.0   2876101.0   2880703.0  ...
# 2  42705368.0  41927007.0  41136546.0  40339329.0  39543154.0  ...
# 3     47321.0     48424.0     49463.0     50448.0     51368.0  ...
# 4     76343.0     75013.0     73837.0     72540.0     71746.0  ...
#
#          2010        2009        2008        2007        2006        2005  \
# 0  28189672.0  27385307.0  26427199.0  25903301.0  25442944.0  24411191.0
# ...

# %%
# filter data for total population
total_population_data = df[df['Series Code'] == 'SP.POP.TOTL']

# %%
# sort data based on total population by 2022
total_population_sorted = total_population_data.sort_values(by='2022',ascending = False)

# %%
total_population_sorted.head(15)
# Out:
#      Series Code        Country Name          2022          2021  \
# 89   SP.POP.TOTL               India  1.417173e+09  1.407564e+09
# 41   SP.POP.TOTL               China  1.412175e+09  1.412360e+09
# 206  SP.POP.TOTL       United States  3.332876e+08  3.320316e+08
# 90   SP.POP.TOTL           Indonesia  2.755013e+08  2.737532e+08
# 149  SP.POP.TOTL            Pakistan  2.358249e+08  2.314021e+08
# 144  SP.POP.TOTL             Nigeria  2.185412e+08  2.134013e+08
# 26   SP.POP.TOTL              Brazil  2.153135e+08  2.143262e+08
# 15   SP.POP.TOTL          Bangladesh  1.711864e+08  1.693563e+08
# 161  SP.POP.TOTL  Russian Federation  1.435557e+08  1.434493e+08
# 127  SP.POP.TOTL              Mexico  1.275041e+08  1.267051e+08
# 98   SP.POP.TOTL               Japan  1.251250e+08  1.256816e+08
# 64   SP.POP.TOTL            Ethiopia  1.233799e+08  1.202830e+08
# 155  SP.POP.TOTL         Philippines  1.155590e+08  1.138803e+08
# ...

# %%
# Get the top 15 countries with the highest total population for 2022
total_top_fifteen_countries = total_population_sorted.head(15)

# %%
print("Top 15 countries with the highest total population by 2022")
total_top_fifteen_countries[['Country Name', '2022']]
# Out:
# Top 15 countries with the highest total population by 2022
#            Country Name          2022
# 89                India  1.417173e+09
# 41                China  1.412175e+09
# 206       United States  3.332876e+08
# 90            Indonesia  2.755013e+08
# 149            Pakistan  2.358249e+08
# 144             Nigeria  2.185412e+08
# 26               Brazil  2.153135e+08
# 15           Bangladesh  1.711864e+08
# 161  Russian Federation  1.435557e+08
# 127              Mexico  1.275041e+08
# 98                Japan  1.251250e+08
# 64             Ethiopia  1.233799e+08
# 155         Philippines  1.155590e+08
# 58     Egypt, Arab Rep.  1.109901e+08
# 44     Congo, Dem. Rep.  9.901021e+07

# %%
print("Top 15 countries with the highest total population by 2001")
total_top_fifteen_countries[['Country Name', '2001']]
# Out:
# Top 15 countries with the highest total population by 2001
#            Country Name          2001
# 89                India  1.078971e+09
# 41                China  1.271850e+09
# 206       United States  2.849690e+08
# 90            Indonesia  2.171124e+08
# 149            Pakistan  1.592177e+08
# 144             Nigeria  1.261527e+08
# 26               Brazil  1.782119e+08
# 15           Bangladesh  1.316705e+08
# 161  Russian Federation  1.459765e+08
# 127              Mexico  9.939429e+07
# 98                Japan  1.271490e+08
# 64             Ethiopia  6.901893e+07
# 155         Philippines  7.962609e+07
# 58     Egypt, Arab Rep.  7.285426e+07
# 44     Congo, Dem. Rep.  5.010666e+07

# %% [markdown]
# ## Bar Plot

# %% [markdown]
# ## Top ten countries of total population in year 2022 and 2016

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Bar Plot for year 2022

plt.figure(figsize = (15,6))
sns.barplot(x = '2022', y = 'Country Name', data = total_top_fifteen_countries,hue="Country Name", palette="coolwarm", legend=False)
plt.title("Top 10 countries of total population in year 2022", fontsize = 15)
plt.xlabel("Total Population", fontsize = 12)
plt.ylabel("Country Name", fontsize = 12)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Bar plot for year 2001

plt.figure(figsize = (15,6))
sns.barplot(x = '2001', y = 'Country Name', data = total_top_fifteen_countries, hue = 'Country Name', palette = 'coolwarm', legend = False)
plt.title("Top 15 Countries of total population in year 2001", fontsize = 15)
plt.xlabel("Total Population", fontsize = 12)
plt.ylabel("Country Name", fontsize = 12)
plt.show()

# %%
# Select top 15 countries based on 2022 population
total_population_sorted = df[df['Series Code'] == 'SP.POP.TOTL'].sort_values(by="2022", ascending=False)
total_top_fifteen_countries = total_population_sorted.head(15)

# Convert the data to long format for easier plotting
df_long = total_top_fifteen_countries.melt(id_vars=["Country Name"], value_vars=["2001", "2022"], 
                                           var_name="Year", value_name="Population")

# Plot the bar chart with hue for year comparison
plt.figure(figsize=(15, 6))
sns.barplot(x="Population", y="Country Name", hue="Year", data=df_long, palette="muted")

# Titles and labels
plt.title("Top 15 Countries by Total Population (2001 vs 2022)", fontsize=12)
plt.xlabel("Total Population", fontsize=10)
plt.ylabel("Country", fontsize=10)
plt.legend(title="Year")
plt.show()

# %% [markdown]
# ## Extraction of bottom-15 countries with respect to total population

# %%
# Sort data based on total population for 2022
total_pop_sorted = total_population_data.sort_values(by = '2022', ascending = True)

# Get the bottom 15 countires with the highest population for 2022
total_bottom_fifteen_countries = total_pop_sorted.head(15)

print("Bottom 15 countries with respect to total population")
print(total_bottom_fifteen_countries[['Country Name', '2022','2001']])
# Out:
# Bottom 15 countries with respect to total population
#                   Country Name     2022     2001
# 201                     Tuvalu  11312.0   9621.0
# 137                      Nauru  12668.0  10363.0
# 150                      Palau  18055.0  19828.0
# 27      British Virgin Islands  31305.0  20657.0
# 183   St. Martin (French part)  31791.0  30387.0
# 75                   Gibraltar  32649.0  27721.0
# 164                 San Marino  33660.0  27335.0
# 130                     Monaco  36469.0  32444.0
# 114              Liechtenstein  39327.0  33376.0
# 124           Marshall Islands  41569.0  54413.0
# 172  Sint Maarten (Dutch part)  43389.0  30600.0
# 3               American Samoa  44273.0  58324.0
# 200   Turks and Caicos Islands  45703.0  19578.0
# 181        St. Kitts and Nevis  47657.0  45986.0
# 146   Northern Mariana Islands  49551.0  79479.0

# %%
# Bar plot for year 2022
plt.figure(figsize = (15,6))
sns.barplot(x = '2022', y = 'Country Name', data = total_bottom_fifteen_countries, hue = 'Country Name', palette = 'coolwarm')
plt.title("Bottom 15 Countries of total population in 2022", fontsize = 15)
plt.xlabel("Total Population", fontsize = 12)
plt.ylabel("Country Name", fontsize = 12)
plt.show()

# %%
# Bar plot for year 2001
plt.figure(figsize = (15,6))
sns.barplot(x = '2001', y = 'Country Name', data = total_bottom_fifteen_countries,hue = 'Country Name', palette = 'coolwarm')
plt.title("Bottom 15 Countries of total population in 2001")
plt.xlabel("Total Population", fontsize = 12)
plt.ylabel("Country Name", fontsize = 12)
plt.show()

# %%
df_long_bottom = total_bottom_fifteen_countries.melt(id_vars = 'Country Name', value_vars = ['2022', '2001'], var_name = 'Year', value_name = 'Population')
plt.figure(figsize = (15,6))
sns.barplot(x = 'Population', y = 'Country Name', data = df_long_bottom, hue = 'Year', palette = 'muted')
plt.title("Bottom 15 countries by total poputation (2022 vs 2001)", fontsize = 12)
plt.xlabel("Total Population", fontsize = 12)
plt.ylabel("Country Name", fontsize = 12)
plt.show()

# %%
Nepal_population = df[(df["Country Name"] == "Nepal") & (df["Series Code"] == "SP.POP.TOTL")]

# %%
Nepal_population
# Out:
#      Series Code Country Name        2022        2021        2020        2019  \
# 138  SP.POP.TOTL        Nepal  30547580.0  30034989.0  29348627.0  28832496.0
#
#            2018        2017        2016        2015  ...        2010  \
# 138  28506712.0  28183426.0  27861186.0  27610325.0  ...  27161567.0
#
#            2009        2008        2007        2006        2005        2004  \
# 138  27026941.0  26881544.0  26713655.0  26518971.0  26285110.0  26003965.0
#
#            2003        2002        2001
# 138  25682908.0  25332178.0  24956071.0
#
# [1 rows x 24 columns]

# %%
#Filter data for Nepal's total population
nepal_population = df[(df["Country Name"] == "Nepal") & (df["Series Code"] == "SP.POP.TOTL")]

# Select only year columns (2001 to 2022)
years = [str(year) for year in range(2001, 2023)]
nepal_population_long = nepal_population.melt(id_vars=["Country Name"], value_vars=years, 
                                              var_name="Year", value_name="Population")

# Convert "Year" column to integer for proper sorting
nepal_population_long["Year"] = nepal_population_long["Year"].astype(int)

# Create a bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x="Year", y="Population", data=nepal_population_long, hue = 'Year', palette="coolwarm", legend = False)

# Add labels, title, and rotate x-axis labels
plt.title("Nepal's Population Growth (2001 - 2022)", fontsize=14)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Total Population", fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Extraction of top fifteen countries with highest male population

# %%
df['Series Code'].unique()
# Out:
# array(['SP.POP.TOTL', 'SP.POP.TOTL.FE.IN', 'SP.POP.TOTL.MA.IN',
#        'SP.POP.TOTL.FE.ZS', 'SP.POP.TOTL.MA.ZS'], dtype=object)

# %%
total_male_population = df[df['Series Code'] == 'SP.POP.TOTL.MA.IN']

# sort data based on total male population for year 2022
sorted_male_population = total_male_population.sort_values(by = "2022", ascending = False)

# top 15 countries with the highest male population for 2022
male_top_fifteen_countries = sorted_male_population.head(15)
print("Top 15 countries with the highest male population for year 2022")
print(male_top_fifteen_countries['Country Name'])
# Out:
# Top 15 countries with the highest male population for year 2022
# 523                 India
# 475                 China
# 640         United States
# 524             Indonesia
# 583              Pakistan
# 578               Nigeria
# 460                Brazil
# 449            Bangladesh
# 595    Russian Federation
# 561                Mexico
# 498              Ethiopia
# 532                 Japan
# 589           Philippines
# 492      Egypt, Arab Rep.
# 478      Congo, Dem. Rep.
# Name: Country Name, dtype: object

# %% [markdown]
# ## Extraction of top fifteen countries with highest female population

# %%
# filter data for female population
total_female_population = df[df['Series Code'] == 'SP.POP.TOTL.FE.IN']

# sort data based on total female population for year 2022
sorted_female_population = total_female_population.sort_values(by = '2022', ascending = False)

# top 15 countries with the highest female population for 2022
female_top_fifteen_countries = sorted_female_population.head(15)
print("Top 15 countries with the highest female population for year 2022")
print(female_top_fifteen_countries['Country Name'])
# Out:
# Top 15 countries with the highest female population for year 2022
# 258                 China
# 306                 India
# 423         United States
# 307             Indonesia
# 366              Pakistan
# 243                Brazil
# 361               Nigeria
# 232            Bangladesh
# 378    Russian Federation
# 344                Mexico
# 315                 Japan
# 281              Ethiopia
# 372           Philippines
# 275      Egypt, Arab Rep.
# 261      Congo, Dem. Rep.
# Name: Country Name, dtype: object

# %% [markdown]
# ### Bar plot for the top 15 male and female population for year 2022

# %%
plt.figure(figsize = (15,6))
sns.barplot(x = "2022", y = "Country Name", data = male_top_fifteen_countries, hue = 'Country Name', palette = 'coolwarm')
plt.title("Top 15 with highest male population (2022)", fontsize = 15)
plt.xlabel("Total Population", fontsize = 12)
plt.ylabel("Country Name", fontsize = 12)
plt.show()

plt.figure(figsize = (15,6))
sns.barplot(x = "2022", y = "Country Name", data = female_top_fifteen_countries,  hue = "Country Name", palette = 'coolwarm')
plt.title("Top 15 countries with highest female population (2022) ", fontsize = 15)
plt.xlabel("Total Population", fontsize = 12)
plt.ylabel("Country Name", fontsize = 12)
plt.show()

# %% [markdown]
# ## Extraction of bottom fifteen countries with lowest male population

# %%
# sort data based on total male population for year 2022
sort_male_population = total_male_population.sort_values(by = "2022", ascending = True)

# top 15 countries with the lowest male population for 2022
male_bottom_fifteen_countries = sort_male_population.head(15)
print("Top 15 countries with the highest male population for year 2022")
print(male_bottom_fifteen_countries['Country Name'])
# Out:
# Top 15 countries with the highest male population for year 2022
# 635                       Tuvalu
# 571                        Nauru
# 584                        Palau
# 461       British Virgin Islands
# 617     St. Martin (French part)
# 509                    Gibraltar
# 598                   San Marino
# 564                       Monaco
# 548                Liechtenstein
# 558             Marshall Islands
# 437               American Samoa
# 634     Turks and Caicos Islands
# 615          St. Kitts and Nevis
# 606    Sint Maarten (Dutch part)
# 580     Northern Mariana Islands
# Name: Country Name, dtype: object

# %% [markdown]
# ## Extraction of bottom fifteen countries with lowest female population

# %%
# sort data based on total female population for year 2022
sort_female_population = total_female_population.sort_values(by = '2022', ascending = True)

# top 15 countries with the highest female population for 2022
female_bottom_fifteen_countries = sort_female_population.head(15)
print("Top 15 countries with the highest female population for year 2022")
print(female_bottom_fifteen_countries['Country Name'])
# Out:
# Top 15 countries with the highest female population for year 2022
# 418                       Tuvalu
# 354                        Nauru
# 367                        Palau
# 244       British Virgin Islands
# 292                    Gibraltar
# 400     St. Martin (French part)
# 381                   San Marino
# 347                       Monaco
# 331                Liechtenstein
# 389    Sint Maarten (Dutch part)
# 341             Marshall Islands
# 220               American Samoa
# 417     Turks and Caicos Islands
# 363     Northern Mariana Islands
# 398          St. Kitts and Nevis
# Name: Country Name, dtype: object

# %% [markdown]
# ### Bar plot for the bottom 15 male and female population for year 2022

# %%
# Bar plot
plt.figure(figsize = (15,6))
sns.barplot(x = '2022', y = 'Country Name', data = male_bottom_fifteen_countries, hue = 'Country Name' ,palette = 'coolwarm')
plt.title("Top 15 countries with lowest male population", fontsize = 15)
plt.xlabel("total population", fontsize = 10)
plt.ylabel("Country Name", fontsize = 10)
plt.show()

plt.figure(figsize = (15,6))
sns.barplot(x = '2022', y = 'Country Name', data = female_bottom_fifteen_countries, hue = 'Country Name' ,palette = 'coolwarm')
plt.title("Top 15 countries with lowest female population", fontsize = 15)
plt.xlabel("total population", fontsize = 10)
plt.ylabel("Country Name", fontsize = 10)
plt.show()

# %% [markdown]
# # Stacked Bar Plot

# %%
# merge male and female population on "Country Name"
merged_data = pd.merge(total_male_population, total_female_population, on = 'Country Name', suffixes = ('_male','_female'))
merged_data.columns
# Out:
# Index(['Series Code_male', 'Country Name', '2022_male', '2021_male',
#        '2020_male', '2019_male', '2018_male', '2017_male', '2016_male',
#        '2015_male', '2014_male', '2013_male', '2012_male', '2011_male',
#        '2010_male', '2009_male', '2008_male', '2007_male', '2006_male',
#        '2005_male', '2004_male', '2003_male', '2002_male', '2001_male',
#        'Series Code_female', '2022_female', '2021_female', '2020_female',
#        '2019_female', '2018_female', '2017_female', '2016_female',
#        '2015_female', '2014_female', '2013_female', '2012_female',
#        '2011_female', '2010_female', '2009_female', '2008_female',
#        '2007_female', '2006_female', '2005_female', '2004_female',
#        '2003_female', '2002_female', '2001_female'],
#       dtype='object')

# %%
# Calculate total population for each country (male + female)
merged_data['Total Population'] = merged_data['2022_male'] + merged_data['2022_female']

# %%
merged_data.columns
# Out:
# Index(['Series Code_male', 'Country Name', '2022_male', '2021_male',
#        '2020_male', '2019_male', '2018_male', '2017_male', '2016_male',
#        '2015_male', '2014_male', '2013_male', '2012_male', '2011_male',
#        '2010_male', '2009_male', '2008_male', '2007_male', '2006_male',
#        '2005_male', '2004_male', '2003_male', '2002_male', '2001_male',
#        'Series Code_female', '2022_female', '2021_female', '2020_female',
#        '2019_female', '2018_female', '2017_female', '2016_female',
#        '2015_female', '2014_female', '2013_female', '2012_female',
#        '2011_female', '2010_female', '2009_female', '2008_female',
#        '2007_female', '2006_female', '2005_female', '2004_female',
#        '2003_female', '2002_female', '2001_female', 'Total Population'],
#       dtype='object')

# %%
merged_data.head()
# Out:
#     Series Code_male    Country Name   2022_male   2021_male   2020_male  \
# 0  SP.POP.TOTL.MA.IN     Afghanistan  20766442.0  20254878.0  19692301.0
# 1  SP.POP.TOTL.MA.IN         Albania   1384548.0   1404454.0   1419264.0
# 2  SP.POP.TOTL.MA.IN         Algeria  22862237.0  22497244.0  22132899.0
# 3  SP.POP.TOTL.MA.IN  American Samoa     21873.0     22289.0     22921.0
# 4  SP.POP.TOTL.MA.IN         Andorra     40786.0     40361.0     39615.0
#
#     2019_male   2018_male   2017_male   2016_male   2015_male  ...  \
# 0  19090409.0  18549862.0  18028696.0  17520861.0  17071446.0  ...
# 1   1428828.0   1435881.0   1440219.0   1442176.0   1444890.0  ...
# 2  21756903.0  21362603.0  20961313.0  20556314.0  20152232.0  ...
# 3     23535.0     24134.0     24701.0     25240.0     25739.0  ...
# 4     38842.0     38071.0     37380.0     36628.0     36188.0  ...
#
#    2009_female  2008_female  2007_female  2006_female  2005_female  \
# ...

# %%
# sort data based on total population 
sort_data = merged_data.sort_values(by = 'Total Population', ascending = False)
sort_data[['Country Name', 'Total Population']].head(10)
# Out:
#            Country Name  Total Population
# 89                India      1.417173e+09
# 41                China      1.412175e+09
# 206       United States      3.332876e+08
# 90            Indonesia      2.755013e+08
# 149            Pakistan      2.358249e+08
# 144             Nigeria      2.185412e+08
# 26               Brazil      2.153135e+08
# 15           Bangladesh      1.711864e+08
# 161  Russian Federation      1.435557e+08
# 127              Mexico      1.275041e+08

# %%
Top_ten_countries = sort_data.head(10)

# %%
# Create the stacked bar plot
plt.figure(figsize=(12, 6))

sns.barplot(x="Country Name", y="2022_female", data=Top_ten_countries, color="red", label="Female Population")
sns.barplot(x="Country Name", y="2022_male", data=Top_ten_countries, bottom=Top_ten_countries["2022_female"], color="green", label="Male Population")
plt.title("Top 10 Countries with Male and Female Populations (2022)", fontsize = 15)
plt.xlabel("Country Name", fontsize = 12)
plt.ylabel("Total Population", fontsize = 12)
plt.legend()
plt.xticks(rotation=45, ha="right")
plt.show()

# %% [markdown]
# ## Bottom 10 Countries with Male and Female Populations (2022)

# %%
sort_data1 = merged_data.sort_values(by = 'Total Population', ascending = True)
bottom_ten_countries = sort_data1.head(10)
bottom_ten_countries
# Out:
#       Series Code_male              Country Name  2022_male  2021_male  \
# 201  SP.POP.TOTL.MA.IN                    Tuvalu     5799.0     5755.0
# 137  SP.POP.TOTL.MA.IN                     Nauru     6435.0     6361.0
# 150  SP.POP.TOTL.MA.IN                     Palau     9376.0     9380.0
# 27   SP.POP.TOTL.MA.IN    British Virgin Islands    15062.0    14976.0
# 183  SP.POP.TOTL.MA.IN  St. Martin (French part)    15111.0    15188.0
# 75   SP.POP.TOTL.MA.IN                 Gibraltar    16308.0    16317.0
# 164  SP.POP.TOTL.MA.IN                San Marino    16380.0    16419.0
# 130  SP.POP.TOTL.MA.IN                    Monaco    17872.0    17982.0
# 114  SP.POP.TOTL.MA.IN             Liechtenstein    19502.0    19354.0
# 124  SP.POP.TOTL.MA.IN          Marshall Islands    21223.0    21483.0
#
#      2020_male  2019_male  2018_male  2017_male  2016_male  2015_male  ...  \
# 201     5702.0     5654.0     5613.0     5598.0     5609.0     5617.0  ...
# ...

# %%
# Create the stacked bar plot
plt.figure(figsize=(12, 6))

sns.barplot(x="Country Name", y="2022_female", data=bottom_ten_countries, color="red", label="Female Population")
sns.barplot(x="Country Name", y="2022_male", data=bottom_ten_countries, bottom=bottom_ten_countries["2022_female"], color="green", label="Male Population")
plt.title("Bottom 10 Countries with Male and Female Populations (2022)", fontsize = 15)
plt.xlabel("Country Name", fontsize = 12)
plt.ylabel("Total Population", fontsize = 12)
plt.legend()
plt.xticks(rotation=45, ha="right")
plt.show()
